# %%
import os
os.chdir("/content/drive/MyDrive/group project/FER")
os.getcwd()
# Out:
# '/content/drive/MyDrive/group project/FER'

# %%
import tensorflow as tf
model = tf.keras.models.load_model("model.h5")

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
#im = Image.open(BytesIO(uploaded["Training_87867.jpg"]))
# Out:
#      <input type="file" id="files-b684f171-cf79-47c1-bbb6-4fcf50253eae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b684f171-cf79-47c1-bbb6-4fcf50253eae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMG_20201008_142650.jpg to IMG_20201008_142650.jpg

# %%
import cv2
import matplotlib.pyplot as plt
im = cv2.imread("/content/drive/MyDrive/group project/FER/PrivateTest_218533.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im)
plt.show()

# %%
#import streamlit as st
from PIL import Image
import os
from numpy import asarray
# from tensorflow.keras.preprocessing.image import img_to_array
# from tensorflow.keras.preprocessing.image import load_img
import numpy as np
import cv2
from PIL import Image
from io import BytesIO
import pandas as pd
import urllib
def preprocess(filepath):
  IMG_SIZE = 48  # 50 in txt-based
  img_array = cv2.imread(filepath, cv2.COLOR_BGR2GRAY)  # read in the image, convert to grayscale
  new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize image to match model's expected sizing
  # plt.imshow(new_array)
  plt.show()
  return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
filepath = "/content/drive/MyDrive/group project/FER/PrivateTest_218533.jpg"
prediction = model.predict([preprocess(filepath)])
print(prediction)
classes = np.argmax(prediction, axis = 1)
cat = ["angry","disgust","fear","happy","neutral","sad","surprise"]
print()
print(cat[classes[0]])
print()
im = cv2.imread("/content/drive/MyDrive/group project/FER/PrivateTest_218533.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im)
plt.show()
# Out:
# [[0. 0. 0. 1. 0. 0. 0.]]
#
# happy
